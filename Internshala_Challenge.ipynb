# %% [markdown]
# <a href="https://colab.research.google.com/github/ParamhansNegi/Classification-using-XGB-and-LGBM/blob/main/Internshala_Challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Internshala Data Science Challenege
# Classification Problem

# %% [markdown]
# ![2020-10-11.png](data:image/png;base64,...)

# %% [markdown]
# # Dataset Provided
# A training dataset
